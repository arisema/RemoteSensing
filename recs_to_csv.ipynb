# %%
import pandas as pd

# %%
recFile = pd.ExcelFile("parameters_data/ToEdit.xlsx")
matchingGuide = pd.read_excel(recFile, "Matching guide", header = [0,1], index_col = [0])

# for name in recFile.sheet_names:
#     print(name)

# %%
matchingGuide = matchingGuide.fillna(0)

# %%
matchingGuide#.replace(False, int(0)).replace(True, int(1))
# Out:
# Data                           Data Rainfall (mm)                              \
# SLM Practices               Experts        < 250  251-500  501-750  751-1000
# Bench terrace           Gizaw Desta           0.0      0.0        1       1.0
# Stone walls             Gizaw Desta           0.0      0.0        1       1.0
# Hillside terrace        Gizaw Desta           1.0      1.0        1       1.0
# Semi-circular bunds     Gizaw Desta           1.0      1.0        1       0.0
# Fanya Juu               Gizaw Desta           0.0      0.0        1       1.0
# Level soil bund         Gizaw Desta           1.0      1.0        1       1.0
# Stone bunds             Gizaw Desta           0.0      0.0        1       1.0
# Stone faced soil bunds  Gizaw Desta           0.0      0.0        1       1.0
# Hillside ditches        Gizaw Desta           1.0      1.0        1       1.0
# Trenches                Gizaw Desta           0.0      1.0        1       1.0
# ...

# %%
matchingGuide = matchingGuide.drop('Experts', axis = 1, level = 1)
matchingGuide
# Out:
# Data                   Rainfall (mm)                                         \
# SLM Practices                 < 250  251-500  501-750  751-1000  1001-1500
# Bench terrace                    0.0      0.0        1       1.0        1.0
# Stone walls                      0.0      0.0        1       1.0        1.0
# Hillside terrace                 1.0      1.0        1       1.0        1.0
# Semi-circular bunds              1.0      1.0        1       0.0        0.0
# Fanya Juu                        0.0      0.0        1       1.0        1.0
# Level soil bund                  1.0      1.0        1       1.0        1.0
# Stone bunds                      0.0      0.0        1       1.0        1.0
# Stone faced soil bunds           0.0      0.0        1       1.0        1.0
# Hillside ditches                 1.0      1.0        1       1.0        0.0
# Trenches                         0.0      1.0        1       1.0        0.0
# ...

# %%
matchingGuide.at[:,'Rainfall']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/remoteSensing/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rainfall'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-86a020cb70e1> in <module>
# ...

# %%
matchingGuide.T
# Out:
#                                    Bench terrace Stone walls   \
# Data               SLM Practices
# Rainfall (mm)       < 250                  False        False
#                    251-500                 False        False
#                    501-750                  True         True
#                    751-1000                 True         True
#                    1001-1500                True         True
# ...                                          ...          ...
# Agro-climatic zone Wet Dega                 True         True
#                    Moist High Dega          True         True
#                    Wet High Dega            True         True
#                    Moist Wurch              True         True
#                    Wet Wurch                True         True
#
#                                    Hillside terrace Semi-circular bunds  \
# Data               SLM Practices
# Rainfall (mm)       < 250                      True                True
# ...

# %%
matchingGuide.to_csv(r"parameters_data/parameters_clarrified.csv")
