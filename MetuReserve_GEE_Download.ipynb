# %%
import rasterio
from rasterio.plot import show
from rasterio.merge import merge

# %%
import tracemalloc

# %%
# %%bash
# ls
# Out:
# Metu Reserve Download-0000000000-0000000000.tif
# Metu Reserve Download-0000000000-0000037888.tif
# Metu Reserve Download-0000037888-0000000000.tif
# Metu Reserve Download-0000037888-0000037888.tif
# MetuReserve_GEE_Download.ipynb

# %%
tracemalloc.start()
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 0.000885MB; Peak was 0.010652MB

# %%
tracemalloc.start()

# %%
try:
    mR0 = rasterio.open('Metu Reserve Download-0000000000-0000000000.tif')
    show(mR0)
except:
    print('File not found')

# %%
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 1453.186888MB; Peak was 8631.087068MB

# %%
tracemalloc.start()

# %%
try:
    mR1 = rasterio.open('Metu Reserve Download-0000000000-0000037888.tif')
    show(mR1)
except:
    print('File not found')

# %%
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 1177.450087MB; Peak was 7061.585873MB

# %%
tracemalloc.start()

# %%
try:
    mR2 = rasterio.open('Metu Reserve Download-0000037888-0000000000.tif')
    show(mR2)
except:
    print('File not found')

# %%
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 203.772188MB; Peak was 1219.50407MB

# %%
tracemalloc.start()

# %%
try:
    mR3 = rasterio.open('Metu Reserve Download-0000037888-0000037888.tif')
    show(mR3)
except:
    print('File not found')

# %%
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 167.138452MB; Peak was 999.838365MB

# %%
def create_mosaic(*rasters):
    mosaic_files = []
    for raster in rasters:
        mosaic_files.append(raster)
    return merge(mosaic_files) # returns [mosaic, out_trans]

# %%
tracemalloc.start()

# %%
mosaic, out_trans = create_mosaic(mR0, mR1, mR2, mR3)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-19-c133b9a1949a> in <module>
# ----> 1 mosaic, out_trans = create_mosaic(mR0, mR1, mR2, mR3)
#
# <ipython-input-17-05c08fdc793e> in create_mosaic(*rasters)
#       3     for raster in rasters:
#       4         mosaic_files.append(raster)
# ----> 5     return merge(mosaic_files) # returns [mosaic, out_trans]
#
# ~/miniconda3/envs/remoteSensing/lib/python3.7/site-packages/rasterio/merge.py in merge(datasets, bounds, res, nodata, precision, indexes, method)
#     243             temp_nodata = temp.mask
#     244
# --> 245         copyto(region, temp, region_nodata, temp_nodata)
#     246
#     247     return dest, output_transform
#
# ~/miniconda3/envs/remoteSensing/lib/python3.7/site-packages/rasterio/merge.py in copyto(old_data, new_data, old_nodata, new_nodata)
#     170     if method == 'first':
# ...

# %%
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage is {current / 10**6}MB; Peak was {peak / 10**6}MB")
tracemalloc.stop()
# Out:
# Current memory usage is 21866.014158MB; Peak was 21866.064948MB
